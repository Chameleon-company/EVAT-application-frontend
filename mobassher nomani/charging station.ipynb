# %%
from geopy.geocoders import Nominatim
import pandas as pd
import geopandas as gpd
import folium
from shapely.geometry import Point
import openrouteservice
import geocoder

# %%
df = pd.read_csv('C:/Users/mobas/OneDrive/Desktop/iMAGE/new.csv')

# %%
df
# Out:
#          cost  charging_points pay_at_location is_operational   latitude  \
# 0     Unknown                1         Unknown        Unknown -31.936252
# 1     Unknown                1         Unknown        Unknown -32.935880
# 2     Unknown                2         Unknown        Unknown -41.218297
# 3     Unknown                8         Unknown        Unknown -34.755480
# 4     Unknown                4         Unknown        Unknown -37.887228
# ...       ...              ...             ...            ...        ...
# 1626  Unknown                1         Unknown        Unknown -33.693647
# 1627  Unknown                1           false           true -31.937153
# 1628  Unknown                1         Unknown        Unknown -35.240510
# 1629  Unknown                1         Unknown        Unknown -33.883580
# 1630  Unknown                3         Unknown           true -38.026662
#
#        longitude            operator       connection_type  \
# 0     115.871531             Unknown               Unknown
# 1     151.643848         ChargePoint        Type 1 (J1772)
# 2     146.412523             Unknown  Type 2 (Socket Only)
# 3     149.720994  Tesla Supercharger               Unknown
# 4     145.082491         Tesla, Inc.               Unknown
# ...          ...                 ...                   ...
# 1626  151.018619      Blink Charging        Type 1 (J1772)
# 1627  115.840552     Chargestar (AU)        Type 1 (J1772)
# 1628  149.087110         ChargePoint            NEMA 5-20R
# 1629  151.191530         ChargePoint            NEMA 5-20R
# 1630  145.209603         ChargePoint        Type 1 (J1772)
#
#                                                 Address
# 0     Kaata Lane, Mount Lawley, City of Vincent, Wes...
# 1     ChargePoint, Montgomery Street, Argenton, Newc...
# 2      Bass Highway, Latrobe, Tasmania, 7307, Australia
# 3     Tesla Supercharger, 201, Sloane Street, Goulbu...
# 4     Tesla Destination Charger, 1341, Dandenong Roa...
# ...                                                 ...
# 1626  3, Allen Way, Round Corner, Dural, Sydney, The...
# 1627  Leederville Parade, Leederville, City of Vince...
# 1628  University of Canberra, University Drive, Bruc...
# 1629  Derby Place, Glebe, Inner West, Sydney, Counci...
# 1630  2, Quality Drive, Dandenong South, Melbourne, ...
#
# [1631 rows x 9 columns]

# %%
map = df[['charging_points', 'operator', 'connection_type', 'Address','latitude', 'longitude']]

# %%
map
# Out:
#       charging_points            operator       connection_type  \
# 0                   1             Unknown               Unknown
# 1                   1         ChargePoint        Type 1 (J1772)
# 2                   2             Unknown  Type 2 (Socket Only)
# 3                   8  Tesla Supercharger               Unknown
# 4                   4         Tesla, Inc.               Unknown
# ...               ...                 ...                   ...
# 1626                1      Blink Charging        Type 1 (J1772)
# 1627                1     Chargestar (AU)        Type 1 (J1772)
# 1628                1         ChargePoint            NEMA 5-20R
# 1629                1         ChargePoint            NEMA 5-20R
# 1630                3         ChargePoint        Type 1 (J1772)
#
#                                                 Address   latitude   longitude
# 0     Kaata Lane, Mount Lawley, City of Vincent, Wes... -31.936252  115.871531
# 1     ChargePoint, Montgomery Street, Argenton, Newc... -32.935880  151.643848
# 2      Bass Highway, Latrobe, Tasmania, 7307, Australia -41.218297  146.412523
# 3     Tesla Supercharger, 201, Sloane Street, Goulbu... -34.755480  149.720994
# 4     Tesla Destination Charger, 1341, Dandenong Roa... -37.887228  145.082491
# ...                                                 ...        ...         ...
# 1626  3, Allen Way, Round Corner, Dural, Sydney, The... -33.693647  151.018619
# 1627  Leederville Parade, Leederville, City of Vince... -31.937153  115.840552
# 1628  University of Canberra, University Drive, Bruc... -35.240510  149.087110
# 1629  Derby Place, Glebe, Inner West, Sydney, Counci... -33.883580  151.191530
# 1630  2, Quality Drive, Dandenong South, Melbourne, ... -38.026662  145.209603
#
# [1631 rows x 6 columns]

# %%
list= map[['Address','charging_points', 'operator', 'connection_type', 'latitude', 'longitude']].values.tolist()

# %%
list
# Out:
# [['Kaata Lane, Mount Lawley, City of Vincent, Western Australia, 6050, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -31.9362523,
#   115.8715309],
#  ['ChargePoint, Montgomery Street, Argenton, Newcastle-Maitland, City of Lake Macquarie, New South Wales, 2284, Australia',
#   1,
#   'ChargePoint',
#   'Type 1 (J1772)',
#   -32.9358797,
#   151.6438477],
#  ['Bass Highway, Latrobe, Tasmania, 7307, Australia',
#   2,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -41.218297,
#   146.4125226],
#  ['Tesla Supercharger, 201, Sloane Street, Goulburn, Goulburn Mulwaree Council, New South Wales, 2580, Australia',
#   8,
#   'Tesla Supercharger',
#   'Unknown',
#   -34.7554799,
#   149.7209942],
#  ['Tesla Destination Charger, 1341, Dandenong Road, Malvern East, Melbourne, City of Stonnington, Victoria, 3145, Australia',
#   4,
#   'Tesla, Inc.',
#   'Unknown',
#   -37.8872284,
#   145.0824905],
#  ['Quality Drive, Dandenong South, Melbourne, City of Greater Dandenong, Victoria, 3175, Australia',
#   2,
#   'Unknown',
#   'Unknown',
#   -38.0270897,
#   145.2116252],
#  ['Red Hill Road, Golden Point, Ballarat, City of Ballarat, Victoria, 3350, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.5753648,
#   143.8664155],
#  ['Nicholson Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#   2,
#   'Museums Victoria',
#   'Unknown',
#   -37.8042881,
#   144.9719796],
#  ['Normanby Road, Notting Hill, Melbourne, City of Monash, Victoria, 3168, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.9054453,
#   145.133609],
#  ['Healesville - Kinglake Road, Healesville, Melbourne, Shire of Yarra Ranges, Victoria, 3777, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.6507196,
#   145.5029836],
#  ['ChargePoint, 1239, Nepean Highway, Cheltenham, Melbourne, City of Kingston, Victoria, 3192, Australia',
#   1,
#   'ChargePoint',
#   'Unknown',
#   -37.9584508,
#   145.0534948],
#  ['107, The Scenic Road, Killcare Heights, Gosford, Central Coast Council, New South Wales, 2257, Australia',
#   1,
#   'Tesla Motors',
#   'Unknown',
#   -33.5212508,
#   151.3749048],
#  ['ChargePoint, Unicentre Road, Keiraville, Wollongong City Council, New South Wales, 2500, Australia',
#   1,
#   'ChargePoint',
#   'Type 1 (J1772)',
#   -34.4075897,
#   150.8812521],
#  ['Tesla Supercharger, Horrocks Highway, Clare, Clare and Gilbert Valleys Council, South Australia, 5453, Australia',
#   4,
#   'Tesla Supercharger',
#   'Unknown',
#   -33.8485098,
#   138.6181952],
#  ['Stuart Highway, Ghan, Macdonnell Region, Northern Territory, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -25.197523,
#   133.2007563],
#  ['Tesla Supercharger, Greek Street, Glebe, Inner West, Sydney, Council of the City of Sydney, New South Wales, 2037, Australia',
#   8,
#   'Tesla Supercharger',
#   'Unknown',
#   -33.8829291,
#   151.1946269],
#  ['357-363, George Street, Quay Quarter, Sydney, Sydney CBD, Sydney, Council of the City of Sydney, New South Wales, 2000, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -33.8682863,
#   151.2063604],
#  ['Glenlyon Road, Brunswick, Melbourne, City of Merri-bek, Victoria, 3056, Australia',
#   1,
#   'Merri-bek City Council',
#   'Unknown',
#   -37.7714237,
#   144.9619656],
#  ['Midland Highway, Sulky, Creswick, Shire of Hepburn, Victoria, 3363, Australia',
#   2,
#   'RACV',
#   'Type 1 (J1772)',
#   -37.4438844,
#   143.8905143],
#  ['Tesla Destination Charger, 338, King Street, Mascot, Sydney, Bayside Council, New South Wales, 2020, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -33.9285142,
#   151.186122],
#  ['Willowdale Shopping Centre, Willowdale Drive, Denham Court, Sydney, Campbelltown City Council, New South Wales, 2565, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -33.9760165,
#   150.8118548],
#  ['ChargePoint, Corporate Drive, Heatherton, Melbourne, City of Kingston, Victoria, 3202, Australia',
#   1,
#   'ChargePoint',
#   'Unknown',
#   -37.9505279,
#   145.080672],
#  ['ChargePoint, Springvale Road, Mulgrave, Melbourne, City of Monash, Victoria, 3170, Australia',
#   1,
#   'ChargePoint',
#   'Unknown',
#   -37.9214395,
#   145.1577067],
#  ['ChargePoint, 235, Springvale Road, Glen Waverley, Melbourne, City of Monash, Victoria, 3150, Australia',
#   1,
#   'ChargePoint',
#   'Unknown',
#   -37.8748303,
#   145.165502],
#  ['Western Foreshore Road, Geelong, City of Greater Geelong, Victoria, 3220, Australia',
#   4,
#   'Unknown',
#   'Unknown',
#   -38.1433232,
#   144.3612324],
#  ['Bogan Street, Parkes, Parkes Shire Council, New South Wales, 2870, Australia',
#   1,
#   'NRMA',
#   'Unknown',
#   -33.1375197,
#   148.1726877],
#  ['Crowley Place, Donnybrook, Shire Of Donnybrook-Balingup, Western Australia, 6239, Australia',
#   3,
#   'RAC',
#   'Unknown',
#   -33.5747389,
#   115.8244911],
#  ['Queen Street, Berry, Shoalhaven City Council, New South Wales, 2535, Australia',
#   1,
#   'NRMA',
#   'Unknown',
#   -34.775569,
#   150.7008205],
#  ['Paterson Street, Launceston, City of Launceston, Tasmania, 7250, Australia',
#   1,
#   'Chargefox',
#   'Type 2 (Socket Only), CHAdeMO',
#   -41.4358155,
#   147.1395575],
#  ['Beach Road, Batemans Bay, Eurobodalla Shire Council, New South Wales, 2536, Australia',
#   1,
#   'NRMA',
#   'CHAdeMO',
#   -35.7084845,
#   150.1752344],
#  ['Tesla Supercharger, Wyong Road, Tuggerah, Central Coast Council, New South Wales, 2259, Australia',
#   1,
#   'Tesla Supercharger',
#   'Unknown',
#   -33.3101932,
#   151.420595],
#  ['Main Street, Oak Park, Melbourne, City of Merri-bek, Victoria, 3044, Australia',
#   3,
#   'Unknown',
#   'Unknown',
#   -37.7237042,
#   144.9209626],
#  ['Kelvin Grove, Preston, Melbourne, City of Darebin, Victoria, 3072, Australia',
#   1,
#   'Darebin City Council',
#   'Unknown',
#   -37.7401175,
#   145.0050847],
#  ['501, Bourke Street, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#   4,
#   'RACV',
#   'Unknown',
#   -37.8160073,
#   144.9597412],
#  ['Langs Lane, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#   1,
#   'Alto Hotel',
#   'Unknown',
#   -37.8163799,
#   144.9547665],
#  ['535, Little Lonsdale Street, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.8132556,
#   144.9559119],
#  ['Hardware Lane, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#   2,
#   'Unknown',
#   'Unknown',
#   -37.8143461,
#   144.9618065],
#  ['300, Flinders Street, East End Theatre District, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#   2,
#   'Unknown',
#   'Unknown',
#   -37.81826,
#   144.9639555],
#  ['114, Flinders Street, East End Theatre District, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#   1,
#   'GreenCo',
#   'Unknown',
#   -37.8162175,
#   144.9707936],
#  ['123, Collins Street, East End Theatre District, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.8153856,
#   144.9700374],
#  ['Flinders Lane, East End Theatre District, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.8144864,
#   144.9730784],
#  ['Bourke Street, East End Theatre District, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#   2,
#   'Secure Parking',
#   'Unknown',
#   -37.8125596,
#   144.9695662],
#  ['Portland Lane, East End Theatre District, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#   1,
#   'QT',
#   'Unknown',
#   -37.813368,
#   144.9681379],
#  ['Cape Paterson - Inverloch Road, Inverloch, Bass Coast Shire, Victoria, 3996, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -38.6490505,
#   145.6858267],
#  ['Osborne Avenue, Clayton South, Melbourne, City of Kingston, Victoria, 3169, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.9430275,
#   145.1184356],
#  ['South Gippsland Highway, Cranbourne, Melbourne, City of Casey, Victoria, 3977, Australia',
#   2,
#   'Evie Networks',
#   'CHAdeMO',
#   -38.0870252,
#   145.279579],
#  ['Ewingsdale Road, Ewingsdale, Byron Shire Council, New South Wales, 2481, Australia',
#   2,
#   'NRMA',
#   'CHAdeMO',
#   -28.636313,
#   153.553519],
#  ['Victoria Harbour Promenade, Victoria Harbour, Docklands, Melbourne, City of Melbourne, Victoria, 3008, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.8188089,
#   144.9426093],
#  ['Prospect Street, Holbrook, Greater Hume Shire Council, New South Wales, 2644, Australia',
#   2,
#   'NRMA',
#   'CHAdeMO',
#   -35.7175328,
#   147.317755],
#  ['EVLink, Anderson Street, Chatswood, Lower North Shore, Sydney, Willoughby City Council, New South Wales, 2067, Australia',
#   2,
#   'EVLink',
#   'Unknown',
#   -33.7965055,
#   151.1833566],
#  ['Waste Road, Hamilton Valley, Albury, Albury City Council, New South Wales, 2641, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -36.0283814,
#   146.8959075],
#  ['Yurika, Elm Street, Cooroy Park, Cooroy, Noosa Shire, Queensland, 4563, Australia',
#   2,
#   'Yurika',
#   'Type 2 (Socket Only), CHAdeMO',
#   -26.4170901,
#   152.9114294],
#  ['Exhibition Street, East End Theatre District, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.8098361,
#   144.9692983],
#  ['Punch Lane, East End Theatre District, Melbourne, City of Melbourne, Victoria, 3000, Australia',
#   1,
#   'Secure Parking',
#   'Unknown',
#   -37.8101221,
#   144.970523],
#  ['470-496, Swanston Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#   1,
#   'Arrow on Swanston',
#   'Unknown',
#   -37.8055148,
#   144.9633222],
#  ['204-218, Lygon Street, Little Italy, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.8022448,
#   144.9669687],
#  ['Nicholson Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia',
#   2,
#   'Melbourne Museum',
#   'Unknown',
#   -37.8044709,
#   144.9733535],
#  ['Munster Terrace, North Melbourne, Melbourne, City of Melbourne, Victoria, 3051, Australia',
#   1,
#   'Jet Charge',
#   'Unknown',
#   -37.8014314,
#   144.9427005],
#  ['Waterfront Way, Docklands, Melbourne, City of Melbourne, Victoria, 3008, Australia',
#   1,
#   'The District Docklands',
#   'Unknown',
#   -37.812617,
#   144.939222],
#  ['Pearl River Road, Docklands, Melbourne, City of Melbourne, Victoria, 3008, Australia',
#   1,
#   'The District Docklands',
#   'Unknown',
#   -37.8129804,
#   144.9370084],
#  ['45, Dudley Street, West Melbourne, Melbourne, City of Melbourne, Victoria, 3003, Australia',
#   1,
#   'Flagstaff City Inn',
#   'Unknown',
#   -37.8100036,
#   144.9509974],
#  ['261, Clarendon Street, South Melbourne, Melbourne, City of Port Phillip, Victoria, 3205, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.8319526,
#   144.9607646],
#  ['21, Bank Street, South Melbourne, Melbourne, City of Port Phillip, Victoria, 3205, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.8322063,
#   144.9692208],
#  ['Hodgins Road, Westpark, Hastings, Melbourne, Shire of Mornington Peninsula, Victoria, 3915, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -38.2998125,
#   145.1705033],
#  ['Little Barber Street, Gunnedah, Gunnedah Shire Council, New South Wales, 2380, Australia',
#   1,
#   'NRMA',
#   'Unknown',
#   -30.9786335,
#   150.2519137],
#  ['The Avenue, Ocean Grove, City of Greater Geelong, Victoria, 3226, Australia',
#   1,
#   'Geelong Regional Libraries',
#   'Unknown',
#   -38.2661166,
#   144.5220013],
#  ['Lloyd Street, Moe, City of Latrobe, Victoria, 3825, Australia',
#   1,
#   'Chargefox',
#   'Unknown',
#   -38.184512,
#   146.2375699],
#  ['NRMA, Orange Avenue, Mildura, Rural City of Mildura, Victoria, 3500, Australia',
#   1,
#   'NRMA',
#   'CHAdeMO',
#   -34.18882,
#   142.162711],
#  ['Laman Street, Cooks Hill, Newcastle, Newcastle-Maitland, City of Newcastle, New South Wales, 2300, Australia',
#   22,
#   'Chargefox',
#   'Unknown',
#   -32.9291638,
#   151.7720103],
#  ['1, Dalgal Way, Forest Lodge, Inner West, Sydney, Council of the City of Sydney, New South Wales, 2037, Australia',
#   22,
#   'Chargefox',
#   'Unknown',
#   -33.8763052,
#   151.1778386],
#  ['Jesmond Central, Drury Street, Heaton, Jesmond, Newcastle, Newcastle-Maitland, City of Newcastle, New South Wales, 2287, Australia',
#   7,
#   'Chargepoint',
#   'Unknown',
#   -32.9028042,
#   151.6906686],
#  ['Silver Street, Randwick, Eastern Suburbs, Sydney, Randwick City Council, New South Wales, 2031, Australia',
#   22,
#   'Chargefox',
#   'Unknown',
#   -33.9138057,
#   151.2391178],
#  ['Chargefox, 4, Defries Avenue, Victoria Square, Zetland, Sydney, Council of the City of Sydney, New South Wales, 2017, Australia',
#   1,
#   'Chargefox',
#   'Unknown',
#   -33.9053712,
#   151.2129122],
#  ['Tesla Supercharger, Taylor Street, Moonee Ponds, Melbourne, City of Moonee Valley, Victoria, 3039, Australia',
#   1,
#   'Tesla Supercharger',
#   'Unknown',
#   -37.7644055,
#   144.9222192],
#  ['Evie Networks, Wild Horse Road, Coochin Creek, Sunshine Coast Regional, Queensland, 4518, Australia',
#   1,
#   'Evie Networks',
#   'Unknown',
#   -26.9182695,
#   152.9964595],
#  ['Swim Pool Deck, St Lucia, Greater Brisbane, Queensland, 4067, Australia',
#   2,
#   'Unknown',
#   'Unknown',
#   -27.4954744,
#   153.0167803],
#  ['Wharing Street, Karuah, Port Stephens Council, New South Wales, 2324, Australia',
#   3,
#   'Chargefox',
#   'CHAdeMO',
#   -32.6539082,
#   151.9625258],
#  ['Evie Networks, Commonwealth Lane, Campbell Town, Northern Midlands, Tasmania, 7210, Australia',
#   2,
#   'Evie Networks',
#   'CHAdeMO',
#   -41.9293446,
#   147.4945273],
#  ['South, South City Square, Woolloongabba, Greater Brisbane, Queensland, 4102, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -27.4921779,
#   153.0412292],
#  ['Tesla Destination Charger, Post Office Hill Road, Coober Pedy, The District Council of Coober Pedy, South Australia, 5723, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -29.0106618,
#   134.7543104],
#  ['Boundary Road, Hadfield, Melbourne, City of Merri-bek, Victoria, 3046, Australia',
#   1,
#   'Chargefox',
#   'CHAdeMO',
#   -37.7189925,
#   144.9614795],
#  ['Kiewa Street, Albury, Albury City Council, New South Wales, 2640, Australia',
#   1,
#   'NRMA',
#   'CHAdeMO',
#   -36.0837898,
#   146.9148011],
#  ['Shepperd Street, Ballarat Central, Ballarat, City of Ballarat, Victoria, 3350, Australia',
#   1,
#   'Chargefox',
#   'CHAdeMO',
#   -37.5613256,
#   143.8623024],
#  ['Orient Street, Batemans Bay, Eurobodalla Shire Council, New South Wales, 2536, Australia',
#   1,
#   'Evie Networks',
#   'Unknown',
#   -35.7099111,
#   150.1774214],
#  ['Tesla Supercharger, Monkland Street, Gympie, Gympie Regional, Queensland, Australia',
#   4,
#   'Tesla Supercharger',
#   'Unknown',
#   -26.1881513,
#   152.6612476],
#  ['Lakes Walk, Cessnock, Cessnock City Council, New South Wales, Australia',
#   1,
#   'NRMA',
#   'Unknown',
#   -32.7742468,
#   151.2946203],
#  ['Munda Street, Randwick, Eastern Suburbs, Sydney, Randwick City Council, New South Wales, 2031, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -33.9306373,
#   151.2464722],
#  ['Douglas Street, Fishermans Bend, Port Melbourne, Melbourne, City of Melbourne, Victoria, 3207, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -37.8244076,
#   144.9244765],
#  ['Breese Parade, Forster, Mid-Coast Council, New South Wales, 2428, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -32.1997712,
#   152.5199677],
#  ['Village Avenue, East Brunswick Village, Brunswick East, Melbourne, City of Merri-bek, Victoria, 3057, Australia',
#   2,
#   'Unknown',
#   'Unknown',
#   -37.7719979,
#   144.9789845],
#  ['Market Street, Balranald, Balranald Shire Council, New South Wales, 2715, Australia',
#   1,
#   'NRMA',
#   'CHAdeMO',
#   -34.6396148,
#   143.5644882],
#  ['Blackburn Road, Clayton, Melbourne, City of Monash, Victoria, 3168, Australia',
#   1,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -37.9208333,
#   145.1400183],
#  ['Lancaster Drive, Canberra, Australian Capital Territory, 2609, Australia',
#   1,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -35.2998964,
#   149.190361],
#  ['London Circuit, City, Canberra, District of Canberra Central, Australian Capital Territory, 2601, Australia',
#   1,
#   'Evie Networks',
#   'CHAdeMO',
#   -35.279627,
#   149.1283604],
#  ['Akuna Street, City, Canberra, District of Canberra Central, Australian Capital Territory, 2601, Australia',
#   4,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -35.2801903,
#   149.1354521],
#  ['Entrance 1, Fyshwick, Canberra, District of Canberra Central, Australian Capital Territory, 2609, Australia',
#   1,
#   'Chargefox',
#   'CHAdeMO',
#   -35.3224367,
#   149.165535],
#  ['Queen Elizabeth Drive, Six Ways, Bondi Beach, Eastern Suburbs, Sydney, Waverley Council, New South Wales, 2026, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -33.8908025,
#   151.2762714],
#  ['Russell Falls Creek Track, Derwent Valley, Tasmania, Australia',
#   1,
#   'Mt Field Visitor Centre',
#   'Type 2 (Socket Only)',
#   -42.6817118,
#   146.7164989],
#  ['Main Street, Southbridge, Huonville, Huon Valley, Tasmania, 7109, Australia',
#   1,
#   'Huon Valley Council',
#   'Type 2 (Socket Only)',
#   -43.0312044,
#   147.0474304],
#  ['Hunter Street, Hobart, City of Hobart, Tasmania, 7000, Australia',
#   1,
#   'TasPorts',
#   'Type 2 (Socket Only)',
#   -42.8816834,
#   147.3354788],
#  ['The Circuit, Brisbane Airport, Greater Brisbane, Queensland, 4008, Australia',
#   4,
#   'Evie Networks',
#   'Unknown',
#   -27.4157668,
#   153.077346],
#  ['Electric Highway Tasmania, North Terrace, Burnie, City of Burnie, Tasmania, 7320, Australia',
#   1,
#   'Electric Highway Tasmania',
#   'Type 2 (Socket Only), CHAdeMO',
#   -41.0498769,
#   145.90733],
#  ['Yurika, Alma Street, Rockhampton City, Rockhampton, Rockhampton Regional, Queensland, 7200, Australia',
#   2,
#   'Yurika',
#   'Type 2 (Socket Only), CHAdeMO',
#   -23.3821063,
#   150.5132751],
#  ['Musgrave Street, Berserker, Rockhampton, Rockhampton Regional, Queensland, 4701, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -23.3558309,
#   150.5222122],
#  ['Corr Road, Caddens, Sydney, Penrith City Council, New South Wales, 2747, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -33.7693688,
#   150.7352534],
#  ['Adam Street, Nannup, Shire Of Nannup, Western Australia, 6275, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -33.9791934,
#   115.7649217],
#  ['Tesla Destination Charger, 246, Anson Street, Orange, Orange City Council, New South Wales, 2800, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -33.280911,
#   149.0994869],
#  ['Tesla Destination Charger, Wallace Lane, Campbells Corner, Canobolas, Orange City Council, New South Wales, 2800, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -33.3333919,
#   149.0432132],
#  ['100, Janefield Drive, Bundoora, Melbourne, City of Whittlesea, Victoria, 3083, Australia',
#   1,
#   'Evie Networks',
#   'Unknown',
#   -37.6784969,
#   145.0730497],
#  ['Miles Street, Tenterfield, Tenterfield Shire Council, New South Wales, 2372, Australia',
#   1,
#   'NRMA',
#   'Unknown',
#   -29.0572225,
#   152.0189641],
#  ['Elpis Road, Opalia, Weir Views, Melbourne, City of Melton, Victoria, 3338, Australia',
#   1,
#   'Evie Networks',
#   'CHAdeMO',
#   -37.7227909,
#   144.5721618],
#  ['John Street, Tanunda, The Barossa Council, South Australia, 5352, Australia',
#   2,
#   'NRMA',
#   'CHAdeMO',
#   -34.524747,
#   138.9586197],
#  ['917, Princes Highway, Springvale, Melbourne, City of Greater Dandenong, Victoria, 3171, Australia',
#   4,
#   'Unknown',
#   'Unknown',
#   -37.9279602,
#   145.1431387],
#  ['Powell Street, Jerilderie, Murrumbidgee Council, New South Wales, 2716, Australia',
#   1,
#   'NRMA',
#   'CHAdeMO',
#   -35.3549489,
#   145.7250878],
#  ['Gold Coast Oceanway, Broadbeach, Gold Coast City, Queensland, 4218, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -28.0293919,
#   153.434591],
#  ['Main Street, Bridport, Dorset, Tasmania, 7262, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -41.0035878,
#   147.3947423],
#  ['Pascoe Street, Apollo Bay, Shire of Colac Otway, Victoria, 3233, Australia',
#   2,
#   'Unknown',
#   'Unknown',
#   -38.757058,
#   143.6683449],
#  ['Tesla, Inc., Mechanics Street, Lakes Plaza, Lakes Entrance, Shire of East Gippsland, Victoria, 3909, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -37.8810561,
#   147.9849476],
#  ['Church Street, Cowes, Bass Coast Shire, Victoria, 3922, Australia',
#   2,
#   'EVolution',
#   'Unknown',
#   -38.4513659,
#   145.2402838],
#  ['Cradle Mountain Road, Pencil Pine, Cradle Mountain, Kentish, Tasmania, 7306, Australia',
#   1,
#   'Tasmanian Parks & Wildlife',
#   'Type 2 (Socket Only)',
#   -41.5824743,
#   145.9366036],
#  ['Tesla Supercharger, Camberwell Grove, Hawthorn East, Melbourne, City of Boroondara, Victoria, 3123, Australia',
#   1,
#   'Tesla Supercharger',
#   'Unknown',
#   -37.8292531,
#   145.056178],
#  ['Yurika, Blomfield Street, Miriam Vale, Gladstone Regional, Queensland, Australia',
#   2,
#   'Yurika',
#   'Type 2 (Socket Only), CHAdeMO',
#   -24.327605,
#   151.5605055],
#  ['Yurika, Graham Street, Ayr CBD, Ayr, Burdekin Shire, Queensland, 4807, Australia',
#   2,
#   'Yurika',
#   'Type 2 (Socket Only), CHAdeMO',
#   -19.5755234,
#   147.404019],
#  ['Palmer Street, South Townsville, Townsville, Townsville City, Queensland, 4810, Australia',
#   1,
#   'ChargeStar',
#   'CHAdeMO',
#   -19.2600757,
#   146.8208282],
#  ['Lakeview Street, Speers Point, Newcastle-Maitland, City of Lake Macquarie, New South Wales, 2284, Australia',
#   1,
#   'Chargefox',
#   'Unknown',
#   -32.9599116,
#   151.6240709],
#  ['Yurika, Bruce Highway, Mode, Mango Hill, North Lakes, Greater Brisbane, City of Moreton Bay, Queensland, 4509, Australia',
#   2,
#   'Yurika',
#   'Type 2 (Socket Only), CHAdeMO',
#   -27.243335,
#   153.0156633],
#  ['Yurika, 3539-3565, Pacific Highway, Slacks Creek, Greater Brisbane, Queensland, 4127, Australia',
#   2,
#   'Yurika',
#   'Type 2 (Socket Only), CHAdeMO',
#   -27.6379161,
#   153.1355179],
#  ['Yurika, South Street, Ipswich, Greater Brisbane, Queensland, 4305, Australia',
#   2,
#   'Yurika',
#   'Type 2 (Socket Only), CHAdeMO',
#   -27.6162053,
#   152.7584677],
#  ['Charging the Regions, Albert Street, Kerang, Shire of Gannawarra, Victoria, 3579, Australia',
#   1,
#   'Charging the Regions',
#   'CHAdeMO',
#   -35.7344119,
#   143.9213354],
#  ['Cowper Street, Wallsend, Newcastle, Newcastle-Maitland, City of Newcastle, New South Wales, 2287, Australia',
#   1,
#   'Tesla',
#   'Unknown',
#   -32.9033741,
#   151.6676792],
#  ['Eastern Road, Yallourn, City of Latrobe, Victoria, 3825, Australia',
#   1,
#   'EnergyAustralia',
#   'CHAdeMO',
#   -38.1805437,
#   146.3477263],
#  ['Tesla, Inc., Torrens Street, Braddon, North Canberra, District of Canberra Central, Australian Capital Territory, 2612, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -35.2745267,
#   149.1333578],
#  ['Tesla, Inc., Esplanade, Regatta Point, Strahan, West Coast, Tasmania, 7468, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -42.1522093,
#   145.3299069],
#  ['Tesla, Inc., Rocky Road, Crackenback, Snowy Monaro Regional Council, New South Wales, 2627, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -36.4459863,
#   148.4516049],
#  ['Tesla Destination Charger, 10, Kosciuszko Road, Jindabyne, Snowy Monaro Regional Council, New South Wales, 2627, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -36.4146819,
#   148.6165569],
#  ['Westfield Shopping Centre, Phillip, District of Woden Valley, Australian Capital Territory, 2606, Australia',
#   1,
#   'Unknown',
#   'Type 1 (J1772)',
#   -35.3457734,
#   149.0857708],
#  ['Tesla, Inc., Richardsons Lane, Coles Bay, Glamorgan-Spring Bay, Tasmania, 7215, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -42.1348216,
#   148.3020342],
#  ['Tesla, Inc., Kings Park Trail, Launceston, City of Launceston, Tasmania, 7250, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -41.4403151,
#   147.1290413],
#  ['Lucas Lane, Acacia Park, Armidale, Armidale Regional Council, New South Wales, 2350, Australia',
#   7,
#   "Peterson's Armidale",
#   'Unknown',
#   -30.555484,
#   151.6821565],
#  ['Tesla Destination Charger, 31, Marsh Street, North Hill, Armidale, Armidale Regional Council, New South Wales, 2350, Australia',
#   2,
#   'Tesla, Inc.',
#   'Type 2 (Socket Only)',
#   -30.5062581,
#   151.6728399],
#  ['Mawson Close, Caves Beach, City of Lake Macquarie, New South Wales, 2281, Australia',
#   1,
#   'Porsche',
#   'Unknown',
#   -33.1048978,
#   151.6482486],
#  ['Weddell Road, North Geelong, Geelong, City of Greater Geelong, Victoria, 3215, Australia',
#   2,
#   'Unknown',
#   'Unknown',
#   -38.1293011,
#   144.3453057],
#  ['Broadway, Herberton, Tablelands Regional, Queensland, 4887, Australia',
#   2,
#   'Tropical North Queensland Electric Vehicle Tourist Drive',
#   'Unknown',
#   -17.3736451,
#   145.3844854],
#  ['Hyde Street, Tusmore, Adelaide, City of Burnside, South Australia, 5065, Australia',
#   1,
#   'Chargefox',
#   'Type 2 (Socket Only)',
#   -34.937999,
#   138.6437536],
#  ['Tesla, Inc., Kent Town Road, Langhorne Creek, Alexandrina Council, South Australia, 5255, Australia',
#   2,
#   'Tesla, Inc.',
#   'Type 2 (Socket Only)',
#   -35.2941487,
#   139.0244883],
#  ['Charging the Regions, Burke Street, Newbridge, Shire of Loddon, Victoria, 3551, Australia',
#   1,
#   'Charging the Regions',
#   'Unknown',
#   -36.7405105,
#   143.9001993],
#  ['Ernest Cavanagh Street, Gungahlin, District of Gungahlin, Australian Capital Territory, 2912, Australia',
#   2,
#   'Unknown',
#   'Unknown',
#   -35.1841062,
#   149.1354639],
#  ['Waverley Gardens Shopping Centre, 371, Police Road, Mulgrave, Melbourne, City of Monash, Victoria, 3170, Australia',
#   22,
#   'Chargefox',
#   'Unknown',
#   -37.9365224,
#   145.1907152],
#  ['Browns Road, Noble Park North, Melbourne, City of Greater Dandenong, Victoria, 3174, Australia',
#   1,
#   'Chargefox',
#   'Unknown',
#   -37.9528827,
#   145.1800698],
#  ['Tesla, Inc., Nelson Street, Rye, Melbourne, Shire of Mornington Peninsula, Victoria, 3941, Australia',
#   2,
#   'Tesla, Inc.',
#   'Unknown',
#   -38.3709259,
#   144.8209256],
#  ['Hotham Avenue, Boddington, Shire Of Boddington, Western Australia, 6390, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -32.8021172,
#   116.4755665],
#  ['Tesla Supercharger, Bell Street, Moe, City of Latrobe, Victoria, 3825, Australia',
#   1,
#   'Tesla Supercharger',
#   'Unknown',
#   -38.172938,
#   146.2590159],
#  ['Tesla Destination Charger, Mowamba Place, Friday Flat Camp, Thredbo, Snowy Monaro Regional Council, New South Wales, 2625, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -36.5049165,
#   148.3045413],
#  ['Charging the Regions, Walsh Lane, Ouyen, Rural City of Mildura, Victoria, 3490, Australia',
#   1,
#   'Charging the Regions',
#   'CHAdeMO',
#   -35.0710089,
#   142.3156162],
#  ['Charging the Regions, Curlewis Street, Swan Hill, Rural City of Swan Hill, Victoria, 3585, Australia',
#   2,
#   'Charging the Regions',
#   'CHAdeMO',
#   -35.3409423,
#   143.5617026],
#  ['Tesla Destination Charger, 1, Elizabeth Street, Merimbula, Bega Valley Shire Council, New South Wales, 2548, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -36.8951652,
#   149.9120037],
#  ['Roy Street, Jeparit, Shire of Hindmarsh, Victoria, 3423, Australia',
#   1,
#   'Linga Network',
#   'Unknown',
#   -36.1423702,
#   141.9878017],
#  ['Yaamba Road (Bruce Highway), Parkhurst, Rockhampton, Rockhampton Regional, Queensland, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -23.2884084,
#   150.5116862],
#  ['Tesla Supercharger, Mornington-Tyabb Road, Mornington, Melbourne, Shire of Mornington Peninsula, Victoria, 3931, Australia',
#   1,
#   'Tesla Supercharger',
#   'Unknown',
#   -38.2344038,
#   145.05112],
#  ['IKEA, 917, Princes Highway, Springvale, Melbourne, City of Greater Dandenong, Victoria, 3171, Australia',
#   4,
#   'IKEA',
#   'Type 2 (Socket Only)',
#   -37.9271751,
#   145.1435899],
#  ['Bell Resources, 123, Pitt Street, Quay Quarter, Sydney, Sydney CBD, Sydney, Council of the City of Sydney, New South Wales, 2000, Australia',
#   1,
#   'Bell Resources',
#   'Unknown',
#   -33.8648195,
#   151.2119085],
#  ['Tesla, Inc., John Street, Blackbutt, South Burnett Regional, Queensland, 4314, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -26.8857922,
#   152.1029637],
#  ['Tesla, Inc., Settlement Point Road, Port Macquarie, Port Macquarie-Hastings Council, New South Wales, 2444, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -31.4071902,
#   152.9007826],
#  ['Skillmans Lane, Coonamble, Coonamble Shire Council, New South Wales, 2829, Australia',
#   1,
#   'NRMA',
#   'Unknown',
#   -30.9527945,
#   148.3878551],
#  ['Neilly Street, Walgett, Walgett Shire Council, New South Wales, 2832, Australia',
#   1,
#   'NRMA',
#   'Unknown',
#   -30.0207154,
#   148.1177704],
#  ['Ararat - Halls Gap Road, Pomonal, Rural City of Ararat, Victoria, Australia',
#   2,
#   'EVUp',
#   'Unknown',
#   -37.1955356,
#   142.6092866],
#  ['Anzac Parade, Maroubra, Eastern Suburbs, Sydney, Randwick City Council, New South Wales, 2035, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.9435652,
#   151.2396953],
#  ['Smidmore Street, Marrickville, Inner West, Sydney, Inner West Council, New South Wales, 2204, Australia',
#   4,
#   'Unknown',
#   'Unknown',
#   -33.9080986,
#   151.1716659],
#  ['Hawker Circuit, Armstrong, Mount Duneed, City of Greater Geelong, Armstrong Creek Urban Growth Area, Victoria, 3217, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -38.2159676,
#   144.3181255],
#  ['McDonalds Drive-Thru, Schofields Village, Schofields, Sydney, Blacktown City Council, New South Wales, 2762, Australia',
#   1,
#   'Evie Networks',
#   'Unknown',
#   -33.7054584,
#   150.8754276],
#  ['Tesla Supercharger, Darlot Street, Horsham, Rural City of Horsham, Victoria, 3400, Australia',
#   3,
#   'Tesla Supercharger',
#   'Unknown',
#   -36.7158552,
#   142.1964354],
#  ['Stowaway Lane, Port Adelaide, Adelaide, City of Port Adelaide Enfield, South Australia, 5015, Australia',
#   2,
#   'Unknown',
#   'Unknown',
#   -34.8437992,
#   138.5042702],
#  ['Dickson Road, Leppington, Sydney, Camden Council, New South Wales, 2179, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -33.9532239,
#   150.8040539],
#  ['chargefox, Light Square, Adelaide, Adelaide City Council, South Australia, 5000, Australia',
#   2,
#   'chargefox',
#   'Type 2 (Socket Only)',
#   -34.9255431,
#   138.5944471],
#  ['Tesla, Harvey Street, Port Broughton, Barunga West Council, South Australia, 5522, Australia',
#   1,
#   'Tesla',
#   'Unknown',
#   -33.5998723,
#   137.9317912],
#  ['Addiscombe Place, Unley Park, Adelaide, City of Unley, South Australia, 5061, Australia',
#   2,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -34.9617279,
#   138.6010902],
#  ['Tesla Destination Charger, Hansen Street, Myponga, The District Council of Yankalilla, South Australia, 5202, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -35.3913107,
#   138.4630733],
#  ['Jetcharge, Norwich Road, Rose Bay, Eastern Suburbs, Sydney, Woollahra Municipal Council, New South Wales, 2029, Australia',
#   2,
#   'Jetcharge',
#   'Type 2 (Socket Only)',
#   -33.871695,
#   151.2681007],
#  ['Tesla Destination Charger, Maitalnd Road, Minlaton, Yorke Peninsula Council, South Australia, 5575, Australia',
#   1,
#   'Tesla, Inc.',
#   'Type 2 (Socket Only)',
#   -34.7678388,
#   137.5974941],
#  ['Liverpool Road, Burwood, Inner West, Sydney, Burwood Council, New South Wales, 2134, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.8872485,
#   151.099324],
#  ['Eyre Highway, Caiguna, Balladonia, Shire Of Dundas, Western Australia, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -32.2708341,
#   125.4872676],
#  ['Ross Street, Wilcannia, Central Darling Shire Council, New South Wales, 2836, Australia',
#   1,
#   'NRMA',
#   'Unknown',
#   -31.5575066,
#   143.3857829],
#  ['Forestville Mall, The Centre, Forestville, Northern Beaches, Sydney, Northern Beaches Council, New South Wales, 2087, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.7620853,
#   151.2141725],
#  ['Dee Why, 4-16, Oaks Avenue, Dee Why Beach, Dee Why, Northern Beaches, Sydney, Northern Beaches Council, New South Wales, 2099, Australia',
#   1,
#   'Jolt',
#   'CHAdeMO',
#   -33.7537328,
#   151.2869932],
#  ['John Flak Avenue, Kingswood, Sydney, Penrith City Council, New South Wales, 2747, Australia',
#   2,
#   'Western Sydney University',
#   'CHAdeMO',
#   -33.7698741,
#   150.7291974],
#  ['Tesla Supercharger, Willmott Avenue, Margaret River, Shire Of Augusta Margaret River, Western Australia, 6285, Australia',
#   3,
#   'Tesla Supercharger',
#   'Unknown',
#   -33.9511802,
#   115.076035],
#  ['Dowling / Lawrence, 30, Dowling Street, Freshwater, Northern Beaches, Sydney, Northern Beaches Council, New South Wales, 2096, Australia',
#   1,
#   'Jolt',
#   'CHAdeMO',
#   -33.7789889,
#   151.283873],
#  ['Morgans Street, Ravensthorpe, Shire Of Ravensthorpe, Western Australia, 6346, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -33.5816984,
#   120.0441758],
#  ['Stanley Street, Peakhurst, St George, Sydney, Georges River Council, New South Wales, 2210, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.9621828,
#   151.063567],
#  ['Tesla, Inc, Lachlan Valley Way, Taragala, Cowra, Cowra Shire Council, New South Wales, 2794, Australia',
#   2,
#   'Tesla, Inc',
#   'Unknown',
#   -33.8354773,
#   148.6817349],
#  ['Spencer Street, Five Dock, Inner West, Sydney, City of Canada Bay Council, New South Wales, 2046, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.8695391,
#   151.116168],
#  ['Brighton Street, Croydon Park, Inner West, Sydney, Burwood Council, New South Wales, 2133, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.8947565,
#   151.1096799],
#  ['Hayward Street, Harvey, Shire Of Harvey, Western Australia, 6220, Australia',
#   2,
#   'Chargefox',
#   'Type 1 (J1772), Type 2 (Socket Only), CHAdeMO',
#   -33.0792151,
#   115.8968022],
#  ['Tesla Destination Charger, Essex Street, Fremantle, City of Fremantle, Western Australia, 6959, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -32.0573845,
#   115.7472283],
#  ['Tesla, Inc., Creek Road, Arno Bay, The District Council of Cleve, South Australia, 5603, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -33.9167278,
#   136.5725086],
#  ['Park Avenue, Burwood, Inner West, Sydney, Burwood Council, New South Wales, 2134, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.873882,
#   151.1019416],
#  ['Goggs Road, Jindalee, Greater Brisbane, Queensland, 4074, Australia',
#   4,
#   'Evie Networks',
#   'Unknown',
#   -27.5338615,
#   152.9489592],
#  ['Bathurst Street, Brewarrina, Brewarrina Shire Council, New South Wales, 2839, Australia',
#   2,
#   'NRMA',
#   'Unknown',
#   -29.9607798,
#   146.8577827],
#  ['Moombara Street, Dapto, Wollongong City Council, New South Wales, 2530, Australia',
#   1,
#   'Evie Networks',
#   'Unknown',
#   -34.4952775,
#   150.7957656],
#  ['ChargePoint, Coles Drive, Ormeau, Gold Coast City, Queensland, 4208, Australia',
#   2,
#   'ChargePoint',
#   'Unknown',
#   -27.7844523,
#   153.2608045],
#  ['Scanlon Drive, Epping, Melbourne, City of Whittlesea, Victoria, 3076, Australia',
#   1,
#   'Evie Networks',
#   'CHAdeMO',
#   -37.6478848,
#   144.9942276],
#  ['Barcham Road, Northshore Brisbane, Hamilton, Greater Brisbane, Queensland, 4007, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -27.444063,
#   153.0819323],
#  ['Waddamana Road, Hilltop, Waddamana, Central Highlands, Tasmania, 7030, Australia',
#   1,
#   'Chargefox',
#   'CHAdeMO',
#   -42.1244723,
#   146.7458333],
#  ['2001, Commerce Drive, Glebe Hill, Howrah, Hobart, City of Clarence, Tasmania, 7018, Australia',
#   1,
#   'Chargefox',
#   'Unknown',
#   -42.8874253,
#   147.4269258],
#  ['Everton Road, Strathfield, Inner West, Sydney, Burwood Council, New South Wales, 2134, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.8720579,
#   151.0954277],
#  ['Casula Mall, Kurrajong Road cycleway, Casula, Sydney, Liverpool City Council, New South Wales, 2170, Australia',
#   2,
#   'Evie Networks',
#   'CHAdeMO',
#   -33.9488297,
#   150.90026],
#  ['Blue Car Park, Chelsea Lane, Brookvale, Northern Beaches, Sydney, Northern Beaches Council, New South Wales, 2100, Australia',
#   4,
#   'Tesla, Inc.',
#   'Unknown',
#   -33.7666354,
#   151.2644147],
#  ['Tesla Destination Charger, Hutchison Street, Coober Pedy, The District Council of Coober Pedy, South Australia, 5723, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -29.022055,
#   134.7584779],
#  ['Hiles Lane, Macdonaldtown, Alexandria, Sydney, Council of the City of Sydney, New South Wales, 2015, Australia',
#   2,
#   'AmpCharge',
#   'Unknown',
#   -33.9021318,
#   151.1999188],
#  ['22, North Street, Forster, Mid-Coast Council, New South Wales, 2428, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -32.1790682,
#   152.5136654],
#  ['Agg Street, Thornbury, Melbourne, City of Darebin, Victoria, 3071, Australia',
#   2,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -37.7637113,
#   145.023233],
#  ['Meddhung Road, Canberra, Australian Capital Territory, 2609, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -35.2954975,
#   149.1869737],
#  ['Mary Street, Noosaville, Noosa Heads, Noosa Shire, Queensland, 4566, Australia',
#   1,
#   'Evie Networks',
#   'Unknown',
#   -26.4004166,
#   153.0644501],
#  ['Morgan Street, Beverly Hills, St George, Sydney, Georges River Council, New South Wales, 2209, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.9492389,
#   151.081218],
#  ['6, Walker Street, Rhodes, Inner West, Sydney, City of Canada Bay Council, New South Wales, 2138, Australia',
#   2,
#   'Chargefox',
#   'Unknown',
#   -33.8300902,
#   151.0860347],
#  ['Thomas Street, Northmead, Sydney, City of Parramatta Council, New South Wales, 2152, Australia',
#   1,
#   'AmpCharge',
#   'CHAdeMO',
#   -33.787764,
#   150.9946067],
#  ['Cook Street, Mortdale, St George, Sydney, Georges River Council, New South Wales, 2223, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.9701906,
#   151.0801412],
#  ['Footbridge Boulevard, Wentworth Point, Sydney, City of Parramatta Council, New South Wales, 2127, Australia',
#   3,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -33.8256295,
#   151.0790514],
#  ['Tesla, Inc., 6-14, Castle Street, Castle Hill, Sydney, The Hills Shire Council, New South Wales, 2154, Australia',
#   3,
#   'Tesla, Inc.',
#   'Type 2 (Socket Only)',
#   -33.7296798,
#   151.0065082],
#  ['Jetcharge, 21, Wells Street, Frankston, Melbourne, City of Frankston, Victoria, 3199, Australia',
#   2,
#   'Jetcharge',
#   'Type 2 (Socket Only)',
#   -38.1438691,
#   145.1227188],
#  ['Little Walker Street Car Park, Casino, Richmond Valley Council, New South Wales, 2470, Australia',
#   1,
#   'NRMA',
#   'Unknown',
#   -28.8659126,
#   153.0483802],
#  ['Vesper Street, Batemans Bay, Eurobodalla Shire Council, New South Wales, 2536, Australia',
#   2,
#   'NRMA',
#   'CHAdeMO',
#   -35.7096667,
#   150.173894],
#  ['4-6, Niangala Close, Belrose, Northern Beaches, Sydney, Northern Beaches Council, New South Wales, 2085, Australia',
#   1,
#   'Evie Networks',
#   'CHAdeMO',
#   -33.7036198,
#   151.2128688],
#  ['Western Highway Service Road, Warrenheip, Ballarat, City of Ballarat, Victoria, 3352, Australia',
#   4,
#   'Evie Networks',
#   'CHAdeMO',
#   -37.5647424,
#   143.934527],
#  ['Pangee Lane, Nyngan, Bogan Shire Council, New South Wales, 2825, Australia',
#   1,
#   'NRMA',
#   'Unknown',
#   -31.5643351,
#   147.1969608],
#  ['Tesla Supercharger, Ramsay Avenue, Mount Gambier, City of Mount Gambier, South Australia, 5290, Australia',
#   1,
#   'Tesla Supercharger',
#   'Unknown',
#   -37.8347592,
#   140.8026216],
#  ['IKEA, 1, Oulton Avenue, Concord West, Inner West, Sydney, City of Canada Bay Council, New South Wales, 2138, Australia',
#   4,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -33.8359626,
#   151.0848349],
#  ['Treacy Street, Hurstville, St George, Sydney, Georges River Council, New South Wales, 2220, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.9678598,
#   151.1060452],
#  ['Broad Arrow Road, Narwee, St George, Sydney, Georges River Council, New South Wales, 2209, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.948437,
#   151.0710625],
#  ['Mons Avenue, West Ryde, Sydney, Council of the City of Ryde, New South Wales, 2114, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.807399,
#   151.0858151],
#  ['The Canopy Lane Cove, Atrium Plaza, Lane Cove, Lower North Shore, Sydney, Lane Cove Municipal Council, New South Wales, 2066, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -33.8130165,
#   151.1694068],
#  ['Charlton Court, Woolner, Darwin, City of Darwin, Northern Territory, 0820, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -12.4307902,
#   130.860126],
#  ['Kitchener Drive, Darwin City, Darwin Waterfront Precinct Municipality, Northern Territory, 0801, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -12.4663857,
#   130.8466989],
#  ['Link Road, Macquarie Park, Sydney, Council of the City of Ryde, New South Wales, 2113, Australia',
#   6,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -33.7755511,
#   151.1094379],
#  ['BP Pulse, North Road, Brighton East, Melbourne, City of Bayside, Victoria, 3187, Australia',
#   6,
#   'BP Pulse',
#   'Unknown',
#   -37.9001349,
#   145.0069973],
#  ['Twynam Street, Narrandera, Narrandera Shire Council, New South Wales, 2700, Australia',
#   1,
#   'NRMA',
#   'CHAdeMO',
#   -34.7464753,
#   146.5498937],
#  ['Snug Tiers Road, Snug, Hobart, Kingborough, Tasmania, 7054, Australia',
#   1,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -43.0708845,
#   147.2343632],
#  ['1, Pottery Lane, Lane Cove, Lower North Shore, Sydney, Lane Cove Municipal Council, New South Wales, 2066, Australia',
#   4,
#   'Unknown',
#   'Unknown',
#   -33.8140858,
#   151.1706842],
#  ['Marion Street, Leichhardt, Inner West, Sydney, Inner West Council, New South Wales, 2040, Australia',
#   1,
#   'Evie Networks',
#   'Unknown',
#   -33.8848452,
#   151.1492145],
#  ['110, Wattletree Road, Armadale, Melbourne, City of Stonnington, Victoria, 3143, Australia',
#   1,
#   'Evie Networks',
#   'CHAdeMO',
#   -37.8631061,
#   145.0268501],
#  ['Glenelg Highway, Lake Bolac, Rural City of Ararat, Victoria, 3351, Australia',
#   1,
#   'EVup',
#   'Unknown',
#   -37.7117289,
#   142.8409671],
#  ['Blair Street, Moama, Murray River Council, New South Wales, 2731, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -36.1135121,
#   144.757421],
#  ['Letitia Street, Oatley, St George, Sydney, Georges River Council, New South Wales, 2223, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.9815934,
#   151.0815506],
#  ['5115, Main Road, Lilydale, City of Launceston, Tasmania, 7268, Australia',
#   1,
#   'Chargefox',
#   'Type 2 (Socket Only)',
#   -41.251906,
#   147.2166221],
#  ['Main Road, Florence Heights, Moonah, Hobart, City of Glenorchy, Tasmania, 7009, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -42.8484746,
#   147.2968239],
#  ['Hooker Boulevard, Broadbeach Waters, Gold Coast City, Queensland, 4218, Australia',
#   4,
#   'Evie Networks',
#   'Unknown',
#   -28.0353151,
#   153.4275587],
#  ['BP Pulse, King Georges Road, Wiley Park, Sydney, Canterbury-Bankstown Council, New South Wales, 2195, Australia',
#   1,
#   'BP Pulse',
#   'CHAdeMO',
#   -33.9195544,
#   151.0669461],
#  ['420, Glen Eira Road, Caulfield, Melbourne, City of Glen Eira, Victoria, 3162, Australia',
#   1,
#   'Foxcharger',
#   'Unknown',
#   -37.8808068,
#   145.0225411],
#  ['Woolworths, Leigh Crescent, Dakabin, Greater Brisbane, City of Moreton Bay, Queensland, 4503, Australia',
#   2,
#   'Woolworths',
#   'CHAdeMO',
#   -27.2290784,
#   152.9908938],
#  ['Coles Bay Road, Swanwick, Coles Bay, Glamorgan-Spring Bay, Tasmania, 7215, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -42.092485,
#   148.2422011],
#  ['Imlay Street, Dunalley, Sorell, Tasmania, 7177, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -42.8870084,
#   147.8145103],
#  ['Tesla Supercharger, Crown Street, Tenterfield, Tenterfield Shire Council, New South Wales, 2372, Australia',
#   4,
#   'Tesla Supercharger',
#   'Unknown',
#   -29.0560795,
#   152.017583],
#  ['Medway Road, Marulan, Goulburn Mulwaree Council, New South Wales, 2579, Australia',
#   1,
#   'BP Pulse',
#   'CHAdeMO',
#   -34.7184231,
#   150.0006494],
#  ['Dawson Street, Miles, Western Downs Regional, Queensland, 4415, Australia',
#   1,
#   'Yurika',
#   'Unknown',
#   -26.6589037,
#   150.1869854],
#  ['5020, University Drive, Campbelltown, Sydney, Campbelltown City Council, New South Wales, 2560, Australia',
#   2,
#   'Chargefox',
#   'Unknown',
#   -34.0678179,
#   150.7889593],
#  ['Johnson Street, Bruce Rock, Shire Of Bruce Rock, Western Australia, 6418, Australia',
#   1,
#   'Unknown',
#   'Unknown',
#   -31.8778574,
#   118.1491738],
#  ['Tesla Supercharger, Ashenden Street, Shepparton, City of Greater Shepparton, Victoria, 3630, Australia',
#   6,
#   'Tesla Supercharger',
#   'Unknown',
#   -36.3843671,
#   145.4009851],
#  ['Lagoon Street, Armstrong Creek, City of Greater Geelong, Armstrong Creek Urban Growth Area, Victoria, 3217, Australia',
#   1,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -38.228002,
#   144.3398434],
#  ['Rowing Course Road, Promised Land, Kentish, Tasmania, 7306, Australia',
#   1,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -41.426075,
#   146.1800703],
#  ['Campbelltown Road, Campbelltown, Sydney, Campbelltown City Council, New South Wales, 2560, Australia',
#   1,
#   'BP Pulse',
#   'Unknown',
#   -34.0532156,
#   150.8236391],
#  ['Montacute Road, Campbelltown, Adelaide, South Australia, 5074, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -34.8885406,
#   138.6731222],
#  ['151-211, Wellington Road, Clayton, Melbourne, City of Monash, Victoria, 3168, Australia',
#   2,
#   'Unknown',
#   'Unknown',
#   -37.908123,
#   145.1319018],
#  ['Sydney Road, Balgowlah, Northern Beaches, Sydney, Northern Beaches Council, New South Wales, 2093, Australia',
#   1,
#   'BP Pulse',
#   'Unknown',
#   -33.7955368,
#   151.2559187],
#  ['Victoria Street, Revesby, Sydney, Canterbury-Bankstown Council, New South Wales, 2212, Australia',
#   1,
#   'BP Pulse',
#   'Unknown',
#   -33.9388196,
#   151.0177286],
#  ['BP Pulse, Clayton Road, Heatherbrae, Newcastle-Maitland, Port Stephens Council, New South Wales, 2324, Australia',
#   2,
#   'BP Pulse',
#   'CHAdeMO',
#   -32.7833007,
#   151.7371187],
#  ['Lagoon Street, Narrabeen, Northern Beaches, Sydney, Northern Beaches Council, New South Wales, 2101, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.713676,
#   151.298355],
#  ['Jersey Street North, Asquith, Sydney, The Council of the Shire of Hornsby, New South Wales, 2077, Australia',
#   2,
#   'BP Pulse',
#   'Unknown',
#   -33.6899794,
#   151.1061283],
#  ['Currie Street, Nambour, Sunshine Coast Regional, Queensland, 4560, Australia',
#   1,
#   'BP Pulse',
#   'Unknown',
#   -26.6312341,
#   152.9607488],
#  ['Bruxner Highway, West Ballina, Ballina Shire Council, New South Wales, 2478, Australia',
#   2,
#   'BP Pulse',
#   'Unknown',
#   -28.8613732,
#   153.5159181],
#  ['Argyle Street, The Rocks, Sydney CBD, Sydney, Council of the City of Sydney, New South Wales, 2000, Australia',
#   2,
#   'City of Sydney',
#   'Unknown',
#   -33.8591188,
#   151.2077898],
#  ['Market Central, 507-553, Lutwyche Road, Lutwyche, Greater Brisbane, Queensland, 4030, Australia',
#   2,
#   'Evie Networks',
#   'Unknown',
#   -27.4221557,
#   153.0344427],
#  ['Darling Drive, Sydney, Sydney CBD, Sydney, Council of the City of Sydney, New South Wales, 2000, Australia',
#   1,
#   'NRMA',
#   'Unknown',
#   -33.8755065,
#   151.1993723],
#  ['Evie at BP Kingston, Canberra Avenue, Manuka, Griffith, South Canberra, District of Canberra Central, Australian Capital Territory, 2603, Australia',
#   1,
#   'Evie Networks',
#   'CHAdeMO',
#   -35.319776,
#   149.1389146],
#  ['Hume Freeway, Wangaratta South, Rural City of Wangaratta, Victoria, 3678, Australia',
#   1,
#   'BP Pulse',
#   'Unknown',
#   -36.4400211,
#   146.2497942],
#  ['Ampol, 1, Horsburgh Drive, Altona North, Melbourne, City of Hobsons Bay, Victoria, 3025, Australia',
#   4,
#   'AmpCharge',
#   'CHAdeMO',
#   -37.8467311,
#   144.8092326],
#  ['Docker Street, Wangaratta, Rural City of Wangaratta, Victoria, 3677, Australia',
#   1,
#   'Evie Networks',
#   'CHAdeMO',
#   -36.354976,
#   146.3224917],
#  ['Victoria Gardens Shopping Centre, 620, Victoria Street, Richmond, Melbourne, City of Yarra, Victoria, 3121, Australia',
#   4,
#   'Unknown',
#   'Unknown',
#   -37.8126532,
#   145.0102415],
#  ['Polly Parade, Emerald Park, Tarneit, Melbourne, City of Wyndham, Victoria, 3029, Australia',
#   1,
#   'Unknown',
#   'Type 2 (Socket Only), CHAdeMO',
#   -37.8252377,
#   144.6830044],
#  ['Engie The Glen, 235, Springvale Road, Glen Waverley, Melbourne, City of Monash, Victoria, 3150, Australia',
#   1,
#   'Engie',
#   'CHAdeMO',
#   -37.8755074,
#   145.1645031],
#  ['Tesla Destination Charger, Walsh Drive, Forest Hill, Wagga Wagga City Council, New South Wales, 2651, Australia',
#   1,
#   'Tesla, Inc.',
#   'Unknown',
#   -35.1582148,
#   147.4595905],
#  ['Winbourne Road, Brookvale, Northern Beaches, Sydney, Northern Beaches Council, New South Wales, 2100, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.7620961,
#   151.2725439],
#  ['Ocean Street, Narrabeen, Northern Beaches, Sydney, Northern Beaches Council, New South Wales, 2101, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.7194247,
#   151.2986321],
#  ['Commercial Street East, Mount Gambier, City of Mount Gambier, South Australia, 5290, Australia',
#   1,
#   'Unknown',
#   'Type 2 (Socket Only)',
#   -37.8323149,
#   140.7933056],
#  ['Kempower, Sandy Bay Road, Sandy Bay, Hobart, City of Hobart, Tasmania, 7005, Australia',
#   1,
#   'Kempower',
#   'CHAdeMO',
#   -42.9031473,
#   147.3365246],
#  ['EVlink, 2335, Mickleham Road, Mickleham, Melbourne, City of Hume, Victoria, 3064, Australia',
#   2,
#   'EVlink',
#   'Unknown',
#   -37.5302783,
#   144.8805475],
#  ['Parramatta Road, Burwood, Inner West, Sydney, Burwood Council, New South Wales, 2134, Australia',
#   1,
#   'Jolt',
#   'Unknown',
#   -33.869384,
#   151.1077617],
#  ['Princes Highway, Fairy Meadow, Wollongong City Council, New South Wales, 2519, Australia',
#   1,
#   'BP Pulse',
#   'Unknown',
#   -34.4033184,
#   150.8914532],
#  ['EVUp, The Strand, North Ward, Townsville, Townsville City, Queensland, 4810, Australia',
#   2,
#   'EVUp',
# ...
#   2,
#   'Evie',
#   'CCS (Type 2)',
#   -35.071065,
#   142.315244],
#  ['Bendigo Art Gallery, 42, View Street, Bendigo, City of Greater Bendigo, Victoria, 3550, Australia',
#   2,
#   'Evie',
#   'CHAdeMO',
#   -36.757619,
#   144.276256],
#  ['Frederick Street, Castlemaine, Shire of Mount Alexander, Victoria, 3450, Australia',
#   2,
#   'Evie',
#   'CHAdeMO',
#   -37.06657645,
#   144.2177713],
#  ['Charging the Regions, High Street, Woodend, Shire of Macedon Ranges, Victoria, 3442, Australia',
#   2,
#   'Evie',
#   'CCS (Type 2)',
#   -37.35582371,
#   144.5288176],
#  ['Ferris Road, Cobblebank, Melbourne, City of Melton, Victoria, 3338, Australia',
#   3,
#   'Chargefox',
#   'CCS (Type 2)',
#   -37.71519008,
#   144.5996763],
#  ['McCracken Drive, McCracken, City of Victor Harbor, South Australia, 5211, Australia',
#   2,
#   'ChargePoint',
#   'Type 1 (J1772)',
#   -35.53437452,
#   138.6368902],
#  ['Sinclair Street, Port Adelaide, Adelaide, City of Port Adelaide Enfield, South Australia, 5015, Australia',
#   1,
#   'Chargefox',
#   'CHAdeMO',
#   -34.84782724,
#   138.5066595],
#  ['Dawson Street, Miles, Western Downs Regional, Queensland, 4415, Australia',
#   1,
#   'Queensland Electric Super Highway',
#   'CCS (Type 2)',
#   -26.65007261,
#   150.1870828],
#  ["Hungry Jack's, 1760, Gympie Road, Somerset, Carseldine, City of Brisbane, Queensland, 4034, Australia",
#   2,
#   '(Unknown Operator)',
#   'CCS (Type 2)',
#   -27.34180168,
#   153.0107295],
#  ['BP Caboolture South Travel Centre, Coach Road East, Burpengary East, Greater Brisbane, City of Moreton Bay, Queensland, 4505, Australia',
#   2,
#   'BP Pulse (AU)',
#   'CCS (Type 2)',
#   -27.12408597,
#   152.9780074],
#  ['BP Caboolture North Travel Centre, Bruce Highway, Burpengary East, Morayfield, Greater Brisbane, City of Moreton Bay, Queensland, 4506, Australia',
#   2,
#   'BP Pulse (AU)',
#   'CHAdeMO',
#   -27.12395187,
#   152.9763902],
#  ['Elm Street, Barcaldine, Barcaldine Regional, Queensland, Australia',
#   1,
#   'Queensland Electric Super Highway',
#   'CCS (Type 2)',
#   -23.55413031,
#   145.2872995],
#  ['Shamrock Street, Blackall, Blackall Tambo Regional, Queensland, Australia',
#   1,
#   'Queensland Electric Super Highway',
#   'CCS (Type 2)',
#   -24.42389008,
#   145.4619167],
#  ['Cypress Street, Charleville, Murweh Shire, Queensland, Australia',
#   1,
#   'Queensland Electric Super Highway',
#   'CCS (Type 2)',
#   -26.41429531,
#   146.2410204],
#  ['Standpipe Golf Motor Inn, Daw Street, Port Augusta West, Port Augusta City Council, South Australia, 5700, Australia',
#   4,
#   '(Unknown Operator)',
#   'Type 2 (Tethered Connector) ',
#   -32.48044078,
#   137.7496148],
#  ['Main South Road, Yankalilla, The District Council of Yankalilla, South Australia, 5203, Australia',
#   3,
#   '(Unknown Operator)',
#   'Type 2 (Tethered Connector) ',
#   -35.457039,
#   138.35117],
#  ['American River Campground, Tangara Drive, American River, Kangaroo Island Council, South Australia, 5221, Australia',
#   1,
#   '(Unknown Operator)',
#   'Type 1 (J1772)',
#   -35.78733355,
#   137.7713531],
#  ['Kingscote Airport, Playford Highway, Kangaroo Island Council, South Australia, Australia',
#   6,
#   '(Unknown Operator)',
#   'Type 1 (J1772)',
#   -35.70877012,
#   137.5232592],
#  ['Yorketown Playground, Stansbury Road, Yorketown, Yorke Peninsula Council, South Australia, 5576, Australia',
#   1,
#   '(Unknown Operator)',
#   'Type 2 (Tethered Connector) ',
#   -35.017566,
#   137.609652],
#  ['Majestic Oasis Apartments, Yuda Street, Port Augusta, Port Augusta City Council, South Australia, 5700, Australia',
#   1,
#   '(Unknown Operator)',
#   'Type 2 (Tethered Connector) ',
#   -32.48888057,
#   137.7628324],
#  ['20, Willyama Drive, Marion Bay, Yorke Peninsula Council, South Australia, 5575, Australia',
#   1,
#   '(Unknown Operator)',
#   'Type 2 (Tethered Connector) ',
#   -35.245411,
#   136.977691],
#  ['Harry Butler Red Devil Memorial, Maitalnd Road, Minlaton, Yorke Peninsula Council, South Australia, 5575, Australia',
#   2,
#   '(Unknown Operator)',
#   'Type 2 (Tethered Connector) ',
#   -34.767943,
#   137.597571],
#  ['Port Vincent Foreshore Caravan Park, 12, Marine Parade, Port Vincent, Yorke Peninsula Council, South Australia, 5581, Australia',
#   1,
#   '(Unknown Operator)',
#   'Type 2 (Tethered Connector) ',
#   -34.778476,
#   137.863902],
#  ['Tesla Destination Charger, First Street, Ardrossan, Yorke Peninsula Council, South Australia, 5571, Australia',
#   1,
#   '(Unknown Operator)',
#   'Type 2 (Tethered Connector) ',
#   -34.422616,
#   137.916796],
#  ['Flint Street, Robe, District Council of Robe, South Australia, 5276, Australia',
#   1,
#   'EO Charging',
#   'Type 2 (Socket Only)',
#   -37.172487,
#   139.75975],
#  ['34, King Street, Hastings, Melbourne, Shire of Mornington Peninsula, Victoria, 3915, Australia',
#   1,
#   'Evie',
#   'CCS (Type 2)',
#   -38.30823,
#   145.191932],
#  ['2, Dunsmuir Drive, Rosebud, Melbourne, Shire of Mornington Peninsula, Victoria, 3939, Australia',
#   2,
#   '(Unknown Operator)',
#   'Unknown',
#   -38.368575,
#   144.905885],
#  ['Morce Avenue, Sorrento, Melbourne, Shire of Mornington Peninsula, Victoria, 3943, Australia',
#   2,
#   'Evie',
#   'CCS (Type 2)',
#   -38.338743,
#   144.7371356],
#  ['Kingston Village Shopping Centre, Grubb Road, Ocean Grove, City of Greater Geelong, Victoria, 3226, Australia',
#   3,
#   'Chargefox',
#   'CCS (Type 2)',
#   -38.24661134,
#   144.5400564],
#  ['Leisurelink Aquatic & Recreation Centre, Pioneer Road, Grovedale, Geelong, City of Greater Geelong, Victoria, 3216, Australia',
#   2,
#   'Chargefox',
#   'CCS (Type 2)',
#   -38.19749674,
#   144.3210374],
#  ['38, Burke Street, Newbridge, Shire of Loddon, Victoria, 3551, Australia',
#   1,
#   'Evie',
#   'CHAdeMO',
#   -36.74044692,
#   143.9001132],
#  ['Charging the Regions, Carrisbrook Settlers Trail, Maryborough, Shire of Central Goldfields, Victoria, 3465, Australia',
#   2,
#   'Evie',
#   'CCS (Type 2)',
#   -37.05084685,
#   143.7414889],
#  ['1A, Hutton Street, Kyneton, Shire of Macedon Ranges, Victoria, 3444, Australia',
#   1,
#   'Evie',
#   'CCS (Type 2)',
#   -37.246931,
#   144.452169],
#  ['76, Vincent Street, Daylesford, Shire of Hepburn, Victoria, 3460, Australia',
#   1,
#   'Chargefox',
#   'CCS (Type 2)',
#   -37.342963,
#   144.142175],
#  ['Torquay Golf Club, Surf Coast Walk, Jan Juc, Surf Coast Shire, Victoria, 3228, Australia',
#   7,
#   'Chargefox',
#   'CCS (Type 2)',
#   -38.34015291,
#   144.3110508],
#  ['Anzac Avenue, Edenhope, Shire of West Wimmera, Victoria, 3318, Australia',
#   1,
#   'Evie',
#   'CCS (Type 2)',
#   -37.036818,
#   141.296757],
#  ['9395, Western Highway, Warrenheip, Ballarat, City of Ballarat, Victoria, 3352, Australia',
#   2,
#   'Evie',
#   'CHAdeMO',
#   -37.564139,
#   143.934273],
#  ['Belvidere Road, Ebenezer, Nuriootpa, The Barossa Council, South Australia, 5355, Australia',
#   10,
#   'Chargefox',
#   'CHAdeMO',
#   -34.460098,
#   138.987775],
#  ['Sarnia Lane, Pasadena, Adelaide, City of Mitcham, South Australia, 5042, Australia',
#   14,
#   '(Unknown Operator)',
#   'CCS (Type 2)',
#   -34.99987618,
#   138.591603],
#  ['Payneham Road, Payneham, Adelaide, The City of Norwood Payneham and St Peters, South Australia, 5070, Australia',
#   1,
#   'Jolt',
#   'CHAdeMO',
#   -34.89565914,
#   138.641422],
#  ['Payneham Road, Payneham, Adelaide, The City of Norwood Payneham and St Peters, South Australia, 5070, Australia',
#   1,
#   'Jolt',
#   'CHAdeMO',
#   -34.89717692,
#   138.6385726],
#  ['Nelson Street, Stepney, Adelaide, The City of Norwood Payneham and St Peters, South Australia, 5069, Australia',
#   1,
#   'Jolt',
#   'CHAdeMO',
#   -34.91105196,
#   138.6288414],
#  ['Stephen Street, Norwood, Adelaide, The City of Norwood Payneham and St Peters, South Australia, 5067, Australia',
#   1,
#   'Jolt',
#   'CHAdeMO',
#   -34.91597918,
#   138.6315031],
#  ['Webbe Street, Norwood, Adelaide, The City of Norwood Payneham and St Peters, South Australia, 5067, Australia',
#   2,
#   'Evie',
#   'CCS (Type 2)',
#   -34.92007383,
#   138.6356244],
#  ['Laver Terrace, Felixstow, Adelaide, The City of Norwood Payneham and St Peters, South Australia, 5070, Australia',
#   1,
#   'Jolt',
#   'CCS (Type 2)',
#   -34.89001666,
#   138.6543937],
#  ['Lower North East Road, Felixstow, Adelaide, The City of Norwood Payneham and St Peters, South Australia, 5070, Australia',
#   2,
#   'Evie',
#   'CHAdeMO',
#   -34.88922848,
#   138.6555789],
#  ['Madden Street North, Kaniva, Shire of West Wimmera, Victoria, 3419, Australia',
#   1,
#   'Evie',
#   'CCS (Type 2)',
#   -36.37766579,
#   141.2382138],
#  ['Liberator Drive, Paralowie, Adelaide, City of Salisbury, South Australia, 5108, Australia',
#   2,
#   'Evie',
#   'CHAdeMO',
#   -34.75909504,
#   138.5955263],
#  ['52, Polly Parade, Emerald Park, Tarneit, Melbourne, City of Wyndham, Victoria, 3029, Australia',
#   1,
#   'Chargefox',
#   'CCS (Type 2)',
#   -37.82495082,
#   144.6818834],
#  ['John McGrath Kia, Magnet Court, Phillip, District of Woden Valley, Australian Capital Territory, 2606, Australia',
#   2,
#   '(Unknown Operator)',
#   'CCS (Type 2)',
#   -35.34916692,
#   149.0851371],
#  ['Vindex Street, Opalton, Winton, Winton Shire, Queensland, Australia',
#   1,
#   'Queensland Electric Super Highway',
#   'CCS (Type 2)',
#   -22.38702913,
#   143.0314724],
#  ['Shire of Denmark, 953, South Coast Highway, Scotsdale, Denmark, Shire Of Denmark, Western Australia, 6333, Australia',
#   2,
#   '(Business Owner at Location)',
#   'Type I (AS 3112)',
#   -34.95949042,
#   117.3662113],
#  ['Shire of Denmark, 953, South Coast Highway, Scotsdale, Denmark, Shire Of Denmark, Western Australia, 6333, Australia',
#   1,
#   '(Business Owner at Location)',
#   'Type I (AS 3112)',
#   -34.95943239,
#   117.3652619],
#  ['Johnson Crescent, Manjimup, Shire Of Manjimup, Western Australia, 6258, Australia',
#   2,
#   'Chargefox',
#   'CCS (Type 2)',
#   -34.2410079,
#   116.1473017],
#  ['South Western Highway, Walpole, Shire Of Manjimup, Western Australia, 6398, Australia',
#   2,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -34.97568634,
#   116.7320012],
#  ['King Street, Cloncurry, Cloncurry Shire, Queensland, Australia',
#   1,
#   'Queensland Electric Super Highway',
#   'CCS (Type 2)',
#   -20.70476029,
#   140.508161],
#  ['Emu Street, Longreach, Longreach Regional, Queensland, Australia',
#   1,
#   'Queensland Electric Super Highway',
#   'CCS (Type 2)',
#   -23.44175714,
#   144.2476667],
#  ['Brodie Street, Hughenden, Flinders Shire, Queensland, Australia',
#   1,
#   'Queensland Electric Super Highway',
#   'CCS (Type 2)',
#   -20.84258159,
#   144.1999692],
#  ['Gordon Street, Richmond Hill, Charters Towers, Charters Towers Regional, Queensland, 4820, Australia',
#   1,
#   'Queensland Electric Super Highway',
#   'CCS (Type 2)',
#   -20.06574729,
#   146.2614358],
#  ['Butler Boulevard, Butler, City of Wanneroo, Western Australia, 6041, Australia',
#   1,
#   'Chargefox',
#   'CCS (Type 2)',
#   -31.63837811,
#   115.6942989],
#  ['Beach Road, Batemans Bay, Eurobodalla Shire Council, New South Wales, 2536, Australia',
#   2,
#   'NRMA',
#   'CHAdeMO',
#   -35.70905218,
#   150.1730602],
#  ['Napier Close, Deakin, Canberra, District of Canberra Central, Australian Capital Territory, 2600, Australia',
#   1,
#   '(Unknown Operator)',
#   'Type I (AS 3112)',
#   -35.32072069,
#   149.0970239],
#  ['Rogan Street, Canberra, Australian Capital Territory, 2609, Australia',
#   2,
#   'Evie',
#   'CCS (Type 2)',
#   -35.30924389,
#   149.1877257],
#  ['WA EV Network - Albany, Residency Road, Albany, City Of Albany, Western Australia, 6330, Australia',
#   2,
#   'WA EV Network (AU)',
#   'CCS (Type 2)',
#   -35.02817641,
#   117.8807717],
#  ['Tesla Supercharger, Festing Street, Albany, City Of Albany, Western Australia, 6330, Australia',
#   6,
#   'Tesla (Tesla-only charging)',
#   'CCS (Type 2)',
#   -35.02798743,
#   117.8806397],
#  ['Rooty Hill Road South, Eastern Creek, Sydney, Blacktown City Council, New South Wales, 2766, Australia',
#   4,
#   '(Unknown Operator)',
#   'Type 2 (Socket Only)',
#   -33.78758418,
#   150.8542683],
#  ['Council Place, East Fremantle, Town of East Fremantle, Western Australia, 6158, Australia',
#   2,
#   '(Unknown Operator)',
#   'Type 2 (Socket Only)',
#   -32.04133322,
#   115.7626909],
#  ['34, Verbena Street, Baranduda Grove Estate, Baranduda, City of Wodonga, Victoria, 3691, Australia',
#   4,
#   'GET Electric (AU)',
#   'Type 2 (Tethered Connector) ',
#   -36.17927,
#   146.947538],
#  ['11-11A, St. Huberts Road, Coldstream, Melbourne, Shire of Yarra Ranges, Victoria, 3770, Australia',
#   6,
#   '(Unknown Operator)',
#   'Type 2 (Socket Only)',
#   -37.69718697,
#   145.4078251],
#  ["Village Street, Batman's Hill, Docklands, Melbourne, City of Melbourne, Victoria, 3008, Australia",
#   8,
#   'GET Electric (AU)',
#   'Type 2 (Tethered Connector) ',
#   -37.82136227,
#   144.9514806],
#  ['Xpeng, 327, Plummer Street, Garden City, Port Melbourne, Melbourne, City of Port Phillip, Victoria, 3207, Australia',
#   6,
#   'GET Electric (AU)',
#   'Type 2 (Socket Only)',
#   -37.83334808,
#   144.9200497],
#  ['James Street, Esperance, Shire Of Esperance, Western Australia, Australia',
#   1,
#   '(Unknown Operator)',
#   'IEC 60309 5-pin',
#   -33.86005133,
#   121.8935609],
#  ['Comfort Inn, The Esplanade, Esperance, Shire Of Esperance, Western Australia, Australia',
#   1,
#   'Tesla (Tesla-only charging)',
#   'Type 2 (Tethered Connector) ',
#   -33.85818474,
#   121.8956987],
#  ['Comfort Inn, The Esplanade, Esperance, Shire Of Esperance, Western Australia, Australia',
#   1,
#   'Tesla (Tesla-only charging)',
#   'Type 2 (Tethered Connector) ',
#   -33.85897266,
#   121.8956527],
#  ['Pinjarra Road, Shire of Murray, Western Australia, Australia',
#   3,
#   'Tesla (Tesla-only charging)',
#   'CCS (Type 2)',
#   -32.55756152,
#   115.7871276],
#  ['Benn Parade, Kojonup, Shire Of Kojonup, Western Australia, 6395, Australia',
#   3,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -33.83760544,
#   117.1577418],
#  ['Norseman Rest Area, Sinclair Street, Norseman, Shire Of Dundas, Western Australia, Australia',
#   2,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -32.19598191,
#   121.7805947],
#  ['Coolgardie Shire Offices and Library, Bayley Street, Coolgardie, Shire Of Coolgardie, Western Australia, 6429, Australia',
#   3,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -30.95427735,
#   121.1611516],
#  ['Grey Street, Northam, Shire Of Northam, Western Australia, 6401, Australia',
#   2,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -31.65218829,
#   116.6719223],
#  ['Hall Street, Halls Creek, Shire of Halls Creek, Western Australia, 6770, Australia',
#   2,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -18.22488086,
#   127.6676972],
#  ['Guwardi Ngadu, 565, Forrest Road, Junjuwa, Fitzroy Crossing, Shire Of Derby-West Kimberley, Western Australia, 6765, Australia',
#   2,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -18.17857664,
#   125.5681912],
#  ['Clarendon Street, Karmulinunga, Derby, Shire Of Derby-West Kimberley, Western Australia, Australia',
#   2,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -17.30523376,
#   123.630758],
#  ['Northampton Visitor Centre, Lot 121, Hampton Road, Northampton, Shire of Northampton, Western Australia, Australia',
#   2,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -28.3518007,
#   114.6308189],
#  ['Grey Street, Kalbarri, Shire of Northampton, Western Australia, Australia',
#   3,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -27.70918863,
#   114.166887],
#  ['Caltex, 131, Indian Ocean Drive, Jurien Bay, Shire Of Dandaragan, Western Australia, 6516, Australia',
#   3,
#   'Chargefox',
#   'CCS (Type 2)',
#   -30.30273755,
#   115.042379],
#  ['Rock Way, Lancelin, Shire Of Gingin, Western Australia, 6044, Australia',
#   3,
#   'Chargefox',
#   'CCS (Type 2)',
#   -31.02060826,
#   115.3325039],
#  ['James Street, Esperance, Shire Of Esperance, Western Australia, Australia',
#   4,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -33.85997275,
#   121.8935147],
#  ['Marine Terrace, Geraldton, City Of Greater Geraldton, Western Australia, 6531, Australia',
#   2,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -28.7763052,
#   114.6037302],
#  ['Orion Street, Southern Cross, Shire Of Yilgarn, Western Australia, Australia',
#   2,
#   'EV Highway (Horizon Power)',
#   'CCS (Type 2)',
#   -31.23361757,
#   119.328694],
#  ['BWS, 55-57, Gilbert Street, Latrobe, Tasmania, 7307, Australia',
#   1,
#   '(Business Owner at Location)',
#   'Type 2 (Socket Only)',
#   -41.23530922,
#   146.4083866],
#  ...]

# %%
aus_map = folium.Map(location=[-41.23530922,146.4083866])
fg=folium.FeatureGroup(name='Ev_map')
for i in list:
    fg.add_child(folium.Marker(location=[i[4],i[5]], popup=[i[0],i[1],i[2],i[3]], icon=folium.Icon(color='green')))
aus_map.add_child(fg)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2bf94bc16be014f24557bed8b03285c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2bf94bc16be014f24557bed8b03285c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2bf94bc16be014f24557bed8b03285c = L.map(
#                 &quot;map_e2bf94bc16be014f24557bed8b03285c&quot;,
#                 {
#                     center: [-41.23530922, 146.4083866],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b22f8769a098572b27131071df4fcd35 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b22f8769a098572b27131071df4fcd35.addTo(map_e2bf94bc16be014f24557bed8b03285c);
#
#
#             var feature_group_d8fe5520a1cc439a5690f139b87d91a6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_42ea3c99379c208c74400430501a9c2c = L.marker(
#                 [-31.9362523, 115.8715309],
#                 {
# }
#             ).addTo(feature_group_d8fe5520a1cc439a5690f139b87d91a6);
#
#
#             var icon_2d6c5d96ab05a4efefdcb14854d35f3d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_42ea3c99379c208c74400430501a9c2c.setIcon(icon_2d6c5d96ab05a4efefdcb14854d35f3d);
#
#
#         var popup_222b639d046382cea03640beb0e6ca75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7b7abc572567a3787ddf0fdf8d70e0d = $(`&lt;div id=&quot;html_b7b7abc572567a3787ddf0fdf8d70e0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;Kaata Lane, Mount Lawley, City of Vincent, Western Australia, 6050, Australia&#x27;, 1, &#x27;Unknown&#x27;, &#x27;Unknown&#x27;]&lt;/div&gt;`)[0];
#                 popup_222b639d046382cea03640beb0e6ca75.setContent(html_b7b7abc572567a3787ddf0fdf8d70e0d);
#
#
#
#         marker_42ea3c99379c208c74400430501a9c2c.bindPopup(popup_222b639d046382cea03640beb0e6ca75)
#         ;
#
#
#
#
#             var marker_d6681c3943e2c6bacd2f8a520607352b = L.marker(
#                 [-32.9358797, 151.6438477],
#                 {
# }
#             ).addTo(feature_group_d8fe5520a1cc439a5690f139b87d91a6);
#
#
#             var icon_04b5b1760a8d398aa2ec7656c84436ba = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d6681c3943e2c6bacd2f8a520607352b.setIcon(icon_04b5b1760a8d398aa2ec7656c84436ba);
#
#
#         var popup_5c10450ddab63596df95cce2e0faa964 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3461d4771efcad3c738b0f02b2437f15 = $(`&lt;div id=&quot;html_3461d4771efcad3c738b0f02b2437f15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;ChargePoint, Montgomery Street, Argenton, Newcastle-Maitland, City of Lake Macquarie, New South Wales, 2284, Australia&#x27;, 1, &#x27;ChargePoint&#x27;, &#x27;Type 1 (J1772)&#x27;]&lt;/div&gt;`)[0];
#                 popup_5c10450ddab63596df95cce2e0faa964.setContent(html_3461d4771efcad3c738b0f02b2437f15);
#
#
#
#         marker_d6681c3943e2c6bacd2f8a520607352b.bindPopup(popup_5c10450ddab63596df95cce2e0faa964)
#         ;
#
#
#
#
#             var marker_66e7eef560b4b554dc8e4b1ebdcd3091 = L.marker(
#                 [-41.218297, 146.4125226],
#                 {
# }
#             ).addTo(feature_group_d8fe5520a1cc439a5690f139b87d91a6);
#
#
#             var icon_937fb962276ca9e1eb31d9d5bd289eaf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_66e7eef560b4b554dc8e4b1ebdcd3091.setIcon(icon_937fb962276ca9e1eb31d9d5bd289eaf);
#
#
#         var popup_2c9957f9b1af1e992169c6c349530b3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79c2ed9252b830abbe8978091eec98d9 = $(`&lt;div id=&quot;html_79c2ed9252b830abbe8978091eec98d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;Bass Highway, Latrobe, Tasmania, 7307, Australia&#x27;, 2, &#x27;Unknown&#x27;, &#x27;Type 2 (Socket Only)&#x27;]&lt;/div&gt;`)[0];
#                 po

# %%
aus_map.save('C:/Users/mobas/OneDrive/Desktop/Aus_map.html')

# %%
current_location = geocoder.ip('me')

if current_location.ok:
    current_coords = (current_location.latlng[0], current_location.latlng[1])
    print(f"Current Location: {current_coords}")
else:
    print("Unable to fetch current location.")
    current_coords = (0, 0)
# Out:
# Current Location: (-37.814, 144.9633)

# %%
charger_gdf = gpd.GeoDataFrame(
    map,
    geometry=gpd.points_from_xy(map.longitude, map.latitude),
    crs="EPSG:3857"
)

# %%
current_point = Point(current_coords[1], current_coords[0])  
charger_gdf['distance'] = charger_gdf.geometry.distance(current_point)
nearest_charger = charger_gdf.loc[charger_gdf['distance'].idxmin()]
print(f"Nearest Charger: {nearest_charger['Address']} at {nearest_charger.geometry}")
# Out:
# Nearest Charger: Hardware Lane, Melbourne, City of Melbourne, Victoria, 3000, Australia at POINT (144.9618065 -37.8143461)

# %%
api_key = "5b3ce3597851110001cf62483ba95147bc4d4f9ba6e44d04127c4d06"  
client = openrouteservice.Client(key=api_key)

# %%
coords = [(current_coords[1], current_coords[0]), 
          (nearest_charger.geometry.x, nearest_charger.geometry.y)]

# %%
route = client.directions(coords, profile='driving-car', format='geojson')

# %%
m = folium.Map(location=current_coords, zoom_start=14)

# %%
folium.Marker(
    location=current_coords,
    popup="Current Location",
    icon=folium.Icon(color='blue')
).add_to(m)

# %%
folium.Marker(
    location=(nearest_charger.geometry.y, nearest_charger.geometry.x),
    popup=nearest_charger['Address'],
    icon=folium.Icon(color='green')
).add_to(m)

# %%
folium.GeoJson(route, name='Route').add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f84bef29c639b2c95c77c7104ba93c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f84bef29c639b2c95c77c7104ba93c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f84bef29c639b2c95c77c7104ba93c6 = L.map(
#                 &quot;map_8f84bef29c639b2c95c77c7104ba93c6&quot;,
#                 {
#                     center: [-37.814, 144.9633],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4830cc257e8bd24312b03953aa95c30d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4830cc257e8bd24312b03953aa95c30d.addTo(map_8f84bef29c639b2c95c77c7104ba93c6);
#
#
#             var marker_80f207280cf00f8497703616aefd783c = L.marker(
#                 [-37.814, 144.9633],
#                 {
# }
#             ).addTo(map_8f84bef29c639b2c95c77c7104ba93c6);
#
#
#             var icon_a5796a4abe81278042df3b17bac4d8c2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_80f207280cf00f8497703616aefd783c.setIcon(icon_a5796a4abe81278042df3b17bac4d8c2);
#
#
#         var popup_071d781270c32c82a8d9e5fc0a76a44f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63a7d6fcd05135a26a59f4780664757e = $(`&lt;div id=&quot;html_63a7d6fcd05135a26a59f4780664757e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Current Location&lt;/div&gt;`)[0];
#                 popup_071d781270c32c82a8d9e5fc0a76a44f.setContent(html_63a7d6fcd05135a26a59f4780664757e);
#
#
#
#         marker_80f207280cf00f8497703616aefd783c.bindPopup(popup_071d781270c32c82a8d9e5fc0a76a44f)
#         ;
#
#
#
#
#             var marker_fcfd8674b1cbd0f1be23e40ab36cd476 = L.marker(
#                 [-37.8143461, 144.9618065],
#                 {
# }
#             ).addTo(map_8f84bef29c639b2c95c77c7104ba93c6);
#
#
#             var icon_92a82130934ab8184cf3da1b461775e7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_fcfd8674b1cbd0f1be23e40ab36cd476.setIcon(icon_92a82130934ab8184cf3da1b461775e7);
#
#
#         var popup_ff2cc93f157385bb1d3fb495c6339b40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_209ad659b1068a6c9028af5983a32748 = $(`&lt;div id=&quot;html_209ad659b1068a6c9028af5983a32748&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hardware Lane, Melbourne, City of Melbourne, Victoria, 3000, Australia&lt;/div&gt;`)[0];
#                 popup_ff2cc93f157385bb1d3fb495c6339b40.setContent(html_209ad659b1068a6c9028af5983a32748);
#
#
#
#         marker_fcfd8674b1cbd0f1be23e40ab36cd476.bindPopup(popup_ff2cc93f157385bb1d3fb495c6339b40)
#         ;
#
#
#
#
#
#         function geo_json_7b56a8d18b88a9beab527401a0a2cdc6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7b56a8d18b88a9beab527401a0a2cdc6 = L.geoJson(null, {
#                 onEachFeature: geo_json_7b56a8d18b88a9beab527401a0a2cdc6_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_7b56a8d18b88a9beab527401a0a2cdc6_add (data) {
#             geo_json_7b56a8d18b88a9beab527401a0a2cdc6
#                 .addData(data);
#         }
#             geo_json_7b56a8d18b88a9beab527401a0a2cdc6_add({&quot;bbox&quot;: [144.961697, -37.814709, 144.963263, -37.814042], &quot;features&quot;: [{&quot;bbox&quot;: [144.961697, -37.814709, 144.963263, -37.814042], &quot;geometry&quot;: {&quot;coordinates&quot;: [[144.963155, -37.814042], [144.963215, -37.814171], [144.963263, -37.814276], [144.963122, -37.814317], [144.962031, -37.814625], [144.961739, -37.814709], [144.961697, -37.814618], [144.961908, -37.814553]], &quot;type&quot;: &quot;LineString&quot;}, &quot;properties&quot;: {&quot;segments&quot;: [{&quot;distance&quot;: 200.8, &quot;duration&quot;: 32.8, &quot;steps&quot;: [{&quot;distance&quot;: 27.7, &quot;duration&quot;: 6.3, &quot;instruction&quot;: &quot;Head south on Elizabeth Street&quot;, &quot;name&quot;: &quot;Elizabeth Street&quot;, &quot;type&quot;: 11, &quot;way_points&quot;: [0, 2]}, {&quot;distance&quot;: 142.3, &quot;duration&quot;: 20.3, &quot;instruction&quot;: &quot;Turn right onto Bourke Street&quot;, &quot;name&quot;: &quot;B
